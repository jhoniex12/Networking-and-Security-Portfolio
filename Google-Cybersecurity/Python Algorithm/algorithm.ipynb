# %%
# Open the file that contains the allow list
allow_list = "allow_list.txt"

with open(allow_list, "r") as file:
    file_content = file.read()
    print (file_content)
# Out:
# 192.168.218.160 192.168.97.225 192.168.145.158 192.168.108.13 192.168.60.153 192.168.96.200 192.168.247.153 192.168.3.252 192.168.116.187 192.168.15.110 192.168.39.246

# %%
# Convert the string into a list
ip_addresses = file_content.split()
print(ip_addresses)
# Out:
# ['192.168.218.160', '192.168.97.225', '192.168.145.158', '192.168.108.13', '192.168.60.153', '192.168.96.200', '192.168.247.153', '192.168.3.252', '192.168.116.187', '192.168.15.110', '192.168.39.246']

# %%
# Iterate through the remove list
remove_list = ["192.168.218.160", "192.168.97.225", "192.168.145.158"]
for element in remove_list:
    print(element)
# Out:
# 192.168.218.160
# 192.168.97.225
# 192.168.145.158

# %%
# Remove IP addresses that are on the remove list
for element in remove_list:
    for ip in ip_addresses:
        if ip == element:
            ip_addresses.remove(element)

print(ip_addresses)
# Out:
# ['192.168.218.160', '192.168.97.225', '192.168.145.158', '192.168.108.13', '192.168.60.153', '192.168.96.200', '192.168.247.153', '192.168.3.252', '192.168.116.187', '192.168.15.110', '192.168.39.246']

# %%
# Update the file with the revised list of IP addresses
ip_addresses = " ".join(ip_addresses)
with open(allow_list, "w") as file:
    file.write(ip_addresses)

# %%
with open(allow_list, "r") as file:
    print(file.read())
# Out:
# 192.168.218.160 192.168.97.225 192.168.145.158 192.168.108.13 192.168.60.153 192.168.96.200 192.168.247.153 192.168.3.252 192.168.116.187 192.168.15.110 192.168.39.246
